# %%
from white_box import ResidualStats
import torch as th

stats = th.load(
    "/mnt/ssd-1/nora/tuned-lenses/pythia/12b-deduped/affine/eval/stream_stats.pt",
    map_location="cpu"
)

# %%
covmats = th.stack(list(stats.covariance()))
covs = covmats.flatten(1)

# %%
L, Q = th.linalg.eigh(covmats)

# %%
trimmed_L = L.clone()
trimmed_L[:, -2:] = 0
trimmed_covmats = Q @ th.diag_embed(trimmed_L) @ Q.mT
trimmed_covs = trimmed_covmats.flatten(1)

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("EleutherAI/pythia-13b-deduped")

# %%
def frobenius_similarities(A):
    A = A.flatten(1)
    gram = A @ A.T
    norms = A.norm(dim=-1, keepdim=True)

    return gram / (norms * norms.T)

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px


TEXT_WIDTH = 6.75 * 96

fig = make_subplots(
    rows=2, cols=1,
    vertical_spacing=0.075,
    # shared_yaxes=True,
    subplot_titles=("all principal components", "w/o top 2 components"),
    x_title="Layer",
    y_title="Layer"
).add_trace(
    go.Heatmap(
        z=frobenius_similarities(covs).cpu(),
        coloraxis="coloraxis",
    ),
    row=1, col=1
).add_trace(
    go.Heatmap(
        z=frobenius_similarities(trimmed_covs).cpu(),
        coloraxis="coloraxis",
    ),
    row=2, col=1
).update_annotations(
    font=dict(size=20, color="black"),
).update_layout(
    coloraxis_colorbar=dict(
        title=dict(
            side="right",
            text="Cosine similarity (Frobenius)",
        )
    ),
    font=dict(size=16, color="black"),
    height=TEXT_WIDTH * 1.5,
    margin_l=70,
    margin_r=30,
    margin_t=30,
    margin_b=70,
    width=TEXT_WIDTH,
    # title="Similarity of covariance across depth (Pythia 12B)"
).update_xaxes(
    dtick=5
).update_yaxes(
    autorange="reversed",
    dtick=5,
)
fig
# Out:
# <div>                            <div id="285b2f8e-e5a6-45c3-98a5-ee1c5e8af0c4" class="plotly-graph-div" style="height:972.0px; width:648.0px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("285b2f8e-e5a6-45c3-98a5-ee1c5e8af0c4")) {                    Plotly.newPlot(                        "285b2f8e-e5a6-45c3-98a5-ee1c5e8af0c4",                        [{"coloraxis":"coloraxis","z":[[1.005935788154602,0.02689236029982567,0.025839587673544884,0.0327482707798481,0.006459677126258612,0.005135965999215841,0.004847378935664892,0.005123292561620474,0.005343475379049778,0.005710763391107321,0.006122151855379343,0.006587059237062931,0.0070483791641891,0.007566237822175026,0.007942747324705124,0.008452149108052254,0.008793623186647892,0.009161337278783321,0.00955723412334919,0.009681702591478825,0.009920991025865078,0.010330851189792156,0.011000770144164562,0.011557466350495815,0.011977159418165684,0.01259869709610939,0.013118759728968143,0.01364747155457735,0.014188637025654316,0.014803072437644005,0.01517350971698761,0.01542368158698082,0.015790283679962158,0.016030829399824142,0.016027770936489105,0.01674814336001873,0.013628216460347176],[0.02689236029982567,1.004662036895752,0.9411516785621643,0.9054815173149109,0.2474876195192337,0.20679867267608643,0.17870545387268066,0.15978272259235382,0.13840295374393463,0.12315423041582108,0.1110290065407753,0.10081806033849716,0.09367535263299942,0.0853491798043251,0.07829321920871735,0.06999418139457703,0.0633021891117096,0.058338433504104614,0.05385304614901543,0.05052239075303078,0.048193272203207016,0.04665356129407883,0.04594903439283371,0.04503612592816353,0.04371720924973488,0.04278503730893135,0.04176141321659088,0.040947284549474716,0.04054149612784386,0.03983757272362709,0.03925700858235359,0.03859647363424301,0.03800836578011513,0.03709755837917328,0.03508744761347771,0.03153965622186661,0.019258806481957436],[0.025839587673544884,0.9411516785621643,1.0035061836242676,0.9750712513923645,0.2951608896255493,0.25154104828834534,0.22132988274097443,0.20043827593326569,0.17655304074287415,0.15918666124343872,0.14495393633842468,0.13268479704856873,0.12388705462217331,0.11353035271167755,0.10464052855968475,0.09402348846197128,0.0852193608880043,0.07847905158996582,0.07240509986877441,0.06766761094331741,0.06427904963493347,0.061833299696445465,0.060565635561943054,0.058942001312971115,0.05673409253358841,0.05498306825757027,0.053188256919384,0.051676634699106216,0.05069158598780632,0.049481093883514404,0.04838960990309715,0.04735927656292915,0.04628355801105499,0.04497310891747475,0.04217168316245079,0.036659907549619675,0.022212810814380646],[0.0327482707798481,0.9054815173149109,0.9750712513923645,1.0044695138931274,0.3111182153224945,0.2670113742351532,0.23673860728740692,0.21612581610679626,0.19218724966049194,0.174730584025383,0.1602632999420166,0.14774669706821442,0.13871602714061737,0.12798722088336945,0.11873585730791092,0.1076522096991539,0.09841420501470566,0.0913580060005188,0.08496200293302536,0.07993105053901672,0.07628672569990158,0.07357244938611984,0.07226140052080154,0.07046595215797424,0.06801869720220566,0.06606736779212952,0.0640539675951004,0.06237274035811424,0.061281535774469376,0.05997307971119881,0.058732323348522186,0.0575634241104126,0.05628819763660431,0.05478544160723686,0.051477257162332535,0.044789038598537445,0.028042588382959366],[0.006459677126258612,0.2474876195192337,0.2951608896255493,0.3111182153224945,0.9999992847442627,0.9967308044433594,0.9928082227706909,0.9870857000350952,0.9791144132614136,0.9713914394378662,0.9640744924545288,0.9565212726593018,0.9501651525497437,0.9418016672134399,0.9328973889350891,0.920016884803772,0.9063053727149963,0.8938804268836975,0.8810290098190308,0.8680914640426636,0.8578624725341797,0.8489482998847961,0.841033935546875,0.83192682266235 ...

# %%
root = "/mnt/ssd-1/nora/tuned-lenses/pythia/12b-deduped/"
vanilla_transfer = th.load(
    root + "affine/eval/aggregate_transfer_metrics.pt", map_location="cpu"
)
penalties = vanilla_transfer['transfer_ce'] - vanilla_transfer['transfer_ce'].diag()

# %%
from white_box.stats import spearmanr

spearmanr(frobenius_similarities(trimmed_covs)[:36, :36].cpu().flatten(), penalties.cpu().flatten())
# Out:
# tensor(-0.7826)

# %%
frobenius_similarities(trimmed_covs)[:36, :36].cpu().flatten().shape
# Out:
# torch.Size([1296])

# %%
penalties.cpu().flatten().shape
# Out:
# torch.Size([1296])

# %%
fig.write_image("/mnt/ssd-1/nora/pythia-12b-cov.pdf")

# %%
import torch.nn.functional as F

stats.covariance().pairwise_map(lambda a, b: F.cosine_similarity(a.flatten(), b.flatten(), dim=0))

# %%
lens_biases = [probe.bias.data.norm() for probe in lens]
lens_biases

# %%
stats.mean().zip_map(lambda mu, b: th.norm(mu + b).item(), lens_biases).plot()
stats.mean().map(lambda mu: th.norm(mu).item()).plot()

# %%
stats.mean().zip_map(lambda mu, b: th.norm(mu + b).item(), lens_biases).plot()

# %%
residuals.mean_norm()

# %%
import matplotlib.pyplot as plt

residuals.mean().map(th.norm).zip_map(lambda g, f: g / f, stats.mean_norm()).map(lambda x: x.cpu()).plot()
plt.yscale('log')

# %%
import torch.distributions as D

dists = stats.mean().zip_map(lambda mu, cov: D.MultivariateNormal(mu, cov), stats.covariance())

# %%
from tuned_lens.stats import gaussian_wasserstein_l2

wass = dists.pairwise_map(gaussian_wasserstein_l2)

# %%
wass.map(lambda x: x.cpu()).plot()

# %%
import torch as th

# %%
stats.mean().map(th.norm).map(lambda x: x.cpu()).plot()
stats.mean_norm().map(lambda x: x.cpu()).plot()
